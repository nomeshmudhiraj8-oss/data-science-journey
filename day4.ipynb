# %% [markdown]
# <a href="https://colab.research.google.com/github/nomeshmudhiraj8-oss/data-science-journey/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' Strings'''
name=input("Enter The Name:")
lastname = "mudhiraj"
print("After concatenation",name+lastname)
# Out:
# Enter The Name:nomesh
# After concatenation nomeshmudhiraj

# %%
''' String Functions'''
''' endswith'''

name = "Nomesh"
print(len(name))
print(name.endswith("esh"))
# Out:
# 6
# True

# %%
name = "Nomesh"
print(name.replace("nomesh","nani"))
print(name.count("n"))
# Out:
# Nomesh
# 0

# %%
name="nomesh"
print(name.replace("nomesh","nani",2))
# Out:
# nani

# %%
a = int(input("Enter A Number:"))
if(a%2==0):
  print(a,":is Divisible By 2")
else:
  print(a,": is not divisible by 2")
# Out:
# Enter A Number:60
# 60 :is Divisible By 2

# %%
a = int(input("Enter A Number:"))
if(a%7==0):
  print(a,":is Divisible By 7")
else:
  print(a,": is not divisible by 7")
# Out:
# Enter A Number:49
# 49 :is Divisible By 7

# %%
a = int(input("Enter a Number:"))
if(a>=90):
  print(a,"is a greatest Number!!!")
elif(a>=70):
  print("Second Highest Number:")
elif(a<=50):
  print("Least highest Number")
# Out:
# Enter a Number:91
# 91 is a greatest Number!!!

# %%
''' ---lists in python--- '''
names = ["Nomesh","Charan","Vishnu"]
marks =[87.5,70.5,74.5]
print(names[0])
print(len(marks))
# Out:
# Nomesh
# 3

# %%
''' list Functions :append,sort,reverse,inser'''
names = ""
