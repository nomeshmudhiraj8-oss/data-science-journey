# %% [markdown]
# <a href="https://colab.research.google.com/github/nomeshmudhiraj8-oss/data-science-journey/blob/main/loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,6):
  '''to print numbers from 1-5'''
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(6):
  print("nomesh mudhiraj")
# Out:
# nomesh mudhiraj
# nomesh mudhiraj
# nomesh mudhiraj
# nomesh mudhiraj
# nomesh mudhiraj
# nomesh mudhiraj

# %%
for i in range(2,21,-2):
  print(i)

# %%
name=input("enter your name:")
for i in range(5):
  print(name)
# Out:
# enter your name:nani
# nani
# nani
# nani
# nani
# nani

# %%
num=int(input("Enter a Number:"))
for i in range(1,31):
  if(i%num==0):
    print(i)
# Out:
# Enter a Number:3
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
i=1
while i<=5:
  print(i)
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 20):
    if i == 5:
      break

    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,21):
  if i==10:
    continue

    print(i)
